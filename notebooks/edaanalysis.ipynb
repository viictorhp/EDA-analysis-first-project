# %% [markdown]
# # EDA ANALYSIS - VICTOR HORCAS

# %% [markdown]
# #### Análisis exploratorio de datos sobre un dataset de los mejores atletas de crsosfit a nivel mundial.

# %% [markdown]
# Importamos todas las librerías que vamos a utilizar en este proyecto.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Exploración de los datos

# %% [markdown]
# Cargamos el dataset escogido para el análisis

# %%
import kagglehub

# %%
crossfit = kagglehub.dataset_download("ulrikthygepedersen/crossfit-athletes")

# %%
crossfit_df = pd.read_csv("D:\\firstprojecteda\\data\\athletes.csv")

# %% [markdown]
# Previsualización de forma general de los datos

# %%
# Base de datos entera
crossfit_df

# %%
# 5 primeras filas
crossfit_df.head (5)
# Out:
#    athlete_id           name               region          team  \
# 0      2554.0      Pj Ablang           South West   Double Edge
# 1      3517.0  Derek Abdella                  NaN           NaN
# 2      4691.0            NaN                  NaN           NaN
# 3      5164.0    Abo Brandon  Southern California  LAX CrossFit
# 4      5286.0    Bryce Abbey                  NaN           NaN
#
#               affiliate gender   age  height  weight   fran  ...  snatch  \
# 0  Double Edge CrossFit   Male  24.0    70.0   166.0    NaN  ...     NaN
# 1                   NaN   Male  42.0    70.0   190.0    NaN  ...     NaN
# 2                   NaN    NaN   NaN     NaN     NaN    NaN  ...     NaN
# 3          LAX CrossFit   Male  40.0    67.0     NaN  211.0  ...   200.0
# 4                   NaN   Male  32.0    65.0   149.0  206.0  ...   150.0
#
#    deadlift  backsq  pullups  \
# 0     400.0   305.0      NaN
# 1       NaN     NaN      NaN
# 2       NaN     NaN      NaN
# ...

# %% [markdown]
# Visualizamos información básica de nuestro dataset y los tipos de datos que contiene

# %%
crossfit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423006 entries, 0 to 423005
# Data columns (total 27 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   athlete_id  423003 non-null  float64
#  1   name        331110 non-null  object
#  2   region      251262 non-null  object
#  3   team        155160 non-null  object
#  4   affiliate   241916 non-null  object
#  5   gender      331110 non-null  object
#  6   age         331110 non-null  float64
#  7   height      159869 non-null  float64
#  8   weight      229890 non-null  float64
#  9   fran        55426 non-null   float64
#  10  helen       30279 non-null   float64
#  11  grace       40745 non-null   float64
#  12  filthy50    19359 non-null   float64
#  13  fgonebad    29738 non-null   float64
#  14  run400      22246 non-null   float64
#  15  run5k       36097 non-null   float64
#  16  candj       104435 non-null  float64
#  17  snatch      97280 non-null   float64
# ...

# %%
crossfit_df.dtypes
# Out:
# athlete_id    float64
# name           object
# region         object
# team           object
# affiliate      object
# gender         object
# age           float64
# height        float64
# weight        float64
# fran          float64
# helen         float64
# grace         float64
# filthy50      float64
# fgonebad      float64
# run400        float64
# run5k         float64
# candj         float64
# snatch        float64
# deadlift      float64
# backsq        float64
# pullups       float64
# eat            object
# train          object
# background     object
# experience     object
# schedule       object
# howlong        object
# dtype: object
