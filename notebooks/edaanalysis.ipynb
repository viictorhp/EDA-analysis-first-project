# %% [markdown]
# # EDA ANALYSIS - VICTOR HORCAS PUERTAS

# %% [markdown]
# Importamos todas las librerías que vamos a utilizar en este proyecto.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
